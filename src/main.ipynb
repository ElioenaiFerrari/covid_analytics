# %%
import pandas as pd
import seaborn as sbn

# %matplotlib inline

dataframe = pd.read_csv('covid.csv')

dataframe.head(10)
# Out:
#   AggregationMethod  ...                                          Geography
# 0             Daily  ...  POLYGON((151.164354085922 -33.9301772341877, 1...
# 1             Daily  ...  POLYGON((151.164354085922 -33.9301772341877, 1...
# 2             Daily  ...  POLYGON((151.164354085922 -33.9301772341877, 1...
# 3             Daily  ...  POLYGON((151.164354085922 -33.9301772341877, 1...
# 4             Daily  ...  POLYGON((151.164354085922 -33.9301772341877, 1...
# 5             Daily  ...  POLYGON((151.164354085922 -33.9301772341877, 1...
# 6             Daily  ...  POLYGON((151.164354085922 -33.9301772341877, 1...
# 7             Daily  ...  POLYGON((151.164354085922 -33.9301772341877, 1...
# 8             Daily  ...  POLYGON((151.164354085922 -33.9301772341877, 1...
# 9             Daily  ...  POLYGON((151.164354085922 -33.9301772341877, 1...
#
# [10 rows x 11 columns]

# %%
sbn.pairplot(dataframe)

# %%
country = dataframe.groupby('Country')

country.describe().head()
# Out:
#                                Version                 ... PercentOfBaseline
#                                  count mean  std  min  ...               25%   50%   75%    max
# Country                                                ...
# Australia                        211.0  1.0  0.0  1.0  ...              19.0  48.0  59.0  100.0
# Canada                          1888.0  1.0  0.0  1.0  ...              62.0  81.0  96.0  100.0
# Chile                            195.0  1.0  0.0  1.0  ...              21.5  29.0  36.0   96.0
# United States of America (the)  3642.0  1.0  0.0  1.0  ...              52.0  64.0  75.0  100.0
#
# [4 rows x 16 columns]
